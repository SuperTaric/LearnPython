# %%
import requests
import json
import random
import time
import pandas as pd
excel_file = 'AT.xlsx'

PC_USER_AGENT = [
    'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)',
    'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)',
    'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)',
    'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; QQDownload 732; .NET4.0C; .NET4.0E)',
    'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; QQDownload 732; .NET4.0C; .NET4.0E; LBBROWSER)',
    'Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.5; AOLBuild 4337.35; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; 360SE)Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 UBrowser/6.2.4094.1 Safari/537.36',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Avant Browser)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Maxthon 2.0)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; TencentTraveler 4.0)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; The World)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0; SE 2.X MetaSr 1.0; SE 2.X MetaSr 1.0; .NET CLR 2.0.50727; SE 2.X MetaSr 1.0)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0; SV1; QQDownload 732; .NET4.0C; .NET4.0E; 360SE)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Acoo Browser; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; .NET4.0E)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; .NET4.0E) QQBrowser/6.9.11079.201',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; .NET4.0E; SE 2.X MetaSr 1.0)',
    'Mozilla/4.0 (compatible; MSIE 7.0b; Windows NT 5.2; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.04506.30)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB7.0)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; InfoPath.3)',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv,2.0.1) Gecko/20100101 Firefox/4.0.1',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_0) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.56 Safari/535.11',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.20 (KHTML, like Gecko) Chrome/19.0.1036.7 Safari/535.20',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.89 Safari/537.1',
    'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/13.0.782.41 Safari/535.1 QQBrowser/6.9.11079.201',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.835.163 Safari/535.1',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.56 Safari/535.11',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.84 Safari/535.11 LBBROWSER',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.11 TaoBrowser/2.0 Safari/536.11',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.71 Safari/537.1 LBBROWSER',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.89 Safari/537.1',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
    'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:6.0) Gecko/20100101 Firefox/6.0',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:2.0b13pre) Gecko/20110307 Firefox/4.0b13pre',
    'Mozilla/5.0 (Windows NT 6.1; rv,2.0.1) Gecko/20100101 Firefox/4.0.1',
    'Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)',
    'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.2pre) Gecko/20070215 K-Ninja/2.1.1',
    'Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)',
    'Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN; rv:1.9) Gecko/20080705 Firefox/3.0 Kapiko/3.0',
    'Mozilla/5.0 (Windows; U; Windows NT 6.1; ) AppleWebKit/534.12 (KHTML, like Gecko) Maxthon/3.0 Safari/534.12',
    'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.3 (KHTML, like Gecko) Chrome/6.0.472.33 Safari/534.3 SE 2.X MetaSr 1.0',
    'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50',
    'Mozilla/5.0 (X11; Linux i686; U;) Gecko/20070322 Kazehakase/0.4.5',
    'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.8) Gecko Fedora/1.9.0.8-1.fc10 Kazehakase/0.5.6',
    'Mozilla/5.0 (X11; U; Linux x86_64; zh-CN; rv:1.9.2.10) Gecko/20100922 Ubuntu/10.10 (maverick) Firefox/3.6.10',
    'Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.6',
    'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:16.0) Gecko/20100101 Firefox/16.0',
    'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 1.0.3705; .NET CLR 1.1.4322)',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; LBBROWSER)',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; QQBrowser/7.0.3698.400)',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; .NET4.0E)',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 2.0.50727; SLCC2; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; Tablet PC 2.0; .NET4.0E)',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 2.0.50727; Media Center PC 6.0)',
    'Mozilla/5.0 (iPad; U; CPU OS 4_2_1 like Mac OS X; zh-cn) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.2 Mobile/8C148 Safari/6533.18.5',
    'Opera/9.80 (Macintosh; Intel Mac OS X 10.6.8; U; fr) Presto/2.9.168 Version/11.52',
    'Opera/9.80 (Windows NT 6.1; U; zh-cn) Presto/2.9.168 Version/11.50',
]

def get_user_agent():
    return random.choice(PC_USER_AGENT)

url = 'https://dc-mkt-prod.cloud.bosch.tech/api/product-search'
headers = {
    'User-Agent': get_user_agent(),
    "Content-Type": "application/json"
}

data = {
    "q":"R900999011",
    "lang":"zh",
    "country":"GD",
    "offset":0,
    "size":10,
    "searchType":"M",
    "sort":"relevance:GD",
    "pimLang":"zh",
    "facets":["shopOrderable","assortName","leadTimePublic","productGroupLevel1"],
    "filters":[]
}

names = []
imgs = []

def post(code):
    try:
        data['q'] = code
        result = requests.post(
            url,
            headers = headers,
            data = json.dumps(data)
        )
        res = result.json()
        print(res)
        first = res['items'][0]
        name = first['termCode'] if 'termCode' in first else (first['termCodeShort']  if 'termCodeShort' in first else '')
        img = first['productImageUrl'] if 'productImageUrl' in first else ''
        names.append(name)
        imgs.append(img)
    except Exception as e:
        names.append('')
        imgs.append('')

df = pd.read_excel(excel_file)
class_dic = df['PN']
print(class_dic)
for c in class_dic:
    post(c)

print(names)
print(imgs)
df = pd.read_excel(excel_file)
df['名称'] = names
df['图片'] = imgs
writer = pd.ExcelWriter(excel_file)
df.to_excel(writer, index=False)
writer.save()
# Out:
# 0      R900205525
# 1      R900572182
# 2      R902531045
# 3      R900777015
# 4      R901246113
#           ...
# 332    R910934966
# 333    R902570169
# 334    R910960737
# 335    R910960739
# 336    R910109479
# Name: PN, Length: 337, dtype: object
# {'totalCount': 1, 'items': [{'sku': 'R900205525', 'comparable': False, 'termCode': '流量控制阀 2FRM6B76-3X/32QMV', 'termCodeShort': '流量控制阀 2FRM6B76-3X/32QMV', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD28163', 'prodHierarchy': '111432063', 'pageId': 'p686894', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD28163', 'prodHierarchy': '111432063', 'pageId': 'p686894', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900572182', 'comparable': True, 'termCode': '流量控制阀 2FRM 6 K2-1X/32QRV', 'termCodeShort': '流量控制阀 2FRM 6 K2-1X/32QRV', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/50f6e2be-c3c9-423c-a52d-537035d705f2/dc_ecommerce_thumbnail_png', 'shortDescription': '2 通流量控制阀', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD28155', 'prodHierarchy': '155431061', 'pageId': 'p686886', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD28155', 'prodHierarchy': '155431061', 'pageId': 'p686886', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_200766', 'name': '最大压力  [bar]', 'type': 'slider', 'range': {'min': 315.0, 'max': 315.0, 'count': 1}}, {'id': 'X50_atr_dc_200767', 'name': '最大体积流量  [l/min]', 'type': 'slider', 'range': {'min': 32.0, 'max': 32.0, 'count': 1}}, {'id': 'X50_atr_dc_200791', 'name': '连接类型', 'type': 'checkbox', 'options': [{'value': '拧入式插装阀', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294624', 'name': '插孔', 'type': 'checkbox', 'options': [{'value': 'M22x1,5', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_ih_108566', 'name': '额定流量  [l/min]', 'type': 'slider', 'range': {'min': 32.0, 'max': 32.0, 'count': 1}}, {'id': 'X50_atr_dc_200790', 'name': '液压油', 'type': 'checkbox', 'options': [{'value': 'HL,HLP,HEES,HEPG', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_3153776', 'name': '产品系列', 'type': 'checkbox', 'options': [{'value': '流量控制器', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_3153797', 'name': '产品类型', 'type': 'checkbox', 'options': [{'value': '2FRM.K', 'count': 1, 'enableNullCount': False}]}]}}
# {'totalCount': 1, 'items': [{'sku': 'R902531045', 'comparable': False, 'termCode': '移换活塞 A4VS 125/180 DR+LR', 'termCodeShort': '移换活塞 A4VS 125/180 DR+LR', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900777015', 'comparable': True, 'termCode': '液压比例方向阀 4WRKE10E50L-3X/6EG24ETK31/F1D3M', 'termCodeShort': '液压比例方向阀 4WRKE10E50L-3X/6EG24ETK31/F1D3M', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/9d2c04f7-acac-4f90-be0a-2a52c0ac95a1/dc_ecommerce_thumbnail_jpg', 'shortDescription': '公称尺寸 10，符号 E，电气带集成电子元件，24 V DC', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD29075', 'prodHierarchy': '112132103', 'pageId': 'p652224', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD29075', 'prodHierarchy': '112132103', 'pageId': 'p652224', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_3631770', 'name': '产品系列', 'type': 'checkbox', 'options': [{'value': '4WRKE', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200766', 'name': '最大压力  [bar]', 'type': 'slider', 'range': {'min': 315.0, 'max': 315.0, 'count': 1}}, {'id': 'X50_atr_dc_200767', 'name': '最大体积流量  [l/min]', 'type': 'slider', 'range': {'min': 170.0, 'max': 170.0, 'count': 1}}, {'id': 'X50_atr_dc_200795', 'name': '活塞符号', 'type': 'checkbox', 'options': [{'value': '符号 E', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200791', 'name': '连接类型', 'type': 'checkbox', 'options': [{'value': '底板安装', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_ih_108566', 'name': '额定流量  [l/min]', 'type': 'slider', 'range': {'min': 50.0, 'max': 50.0, 'count': 1}}, {'id': 'X50_atr_dc_294642', 'name': '标称尺寸', 'type': 'checkbox', 'options': [{'value': '10', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200793', 'name': '驱动类型', 'type': 'checkbox', 'options': [{'value': '电气带集成电子元件', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294631', 'name': '电源电压', 'type': 'checkbox', 'options': [{'value': '24 VDC', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294634', 'name': '电插头', 'type': 'checkbox', 'options': [{'value': '7 针连接器 (6 + PE)', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200772', 'name': '连接', 'type': 'checkbox', 'options': [{'value': '模拟，设定值 4 … 20 mA', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200790', 'name': '液压油', 'type': 'checkbox', 'options': [{'value': 'HL,HLP,HLPD,HVLP,HVLPD,HFC', 'count': 1, 'enableNullCount': False}]}]}}
# {'totalCount': 1, 'items': [{'sku': 'R901246113', 'comparable': False, 'termCode': '液压比例方向阀 4WRKE16E200L-3X/6EG24ETK31/F1D3V', 'termCodeShort': '液压比例方向阀 4WRKE16E200L-3X/6EG24ETK31/F1D3V', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD29075', 'prodHierarchy': '112132163', 'pageId': 'p652224', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD29075', 'prodHierarchy': '112132163', 'pageId': 'p652224', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900751114', 'comparable': False, 'termCode': '液压比例方向阀 4WRKE16W8-200L-3X/6EG24EK31/F1D3M', 'termCodeShort': '液压比例方向阀 4WRKE16W8-200L-3X/6EG24EK31/F1D3M', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD29075', 'prodHierarchy': '112132163', 'pageId': 'p652224', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD29075', 'prodHierarchy': '112132163', 'pageId': 'p652224', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R901005192', 'comparable': True, 'termCode': '液压比例方向阀 4WRKE25W6-220L-3X/6EG24EK31/A1D3M', 'termCodeShort': '液压比例方向阀 4WRKE25W6-220L-3X/6EG24EK31/A1D3M', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/9d2c04f7-acac-4f90-be0a-2a52c0ac95a1/dc_ecommerce_thumbnail_jpg', 'shortDescription': '公称尺寸 25，符号 W6，电气带集成电子元件，24 V DC', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD29075', 'prodHierarchy': '112132253', 'pageId': 'p652224', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD29075', 'prodHierarchy': '112132253', 'pageId': 'p652224', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_3631770', 'name': '产品系列', 'type': 'checkbox', 'options': [{'value': '4WRKE', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200766', 'name': '最大压力  [bar]', 'type': 'slider', 'range': {'min': 350.0, 'max': 350.0, 'count': 1}}, {'id': 'X50_atr_dc_200767', 'name': '最大体积流量  [l/min]', 'type': 'slider', 'range': {'min': 870.0, 'max': 870.0, 'count': 1}}, {'id': 'X50_atr_dc_200795', 'name': '活塞符号', 'type': 'checkbox', 'options': [{'value': '符号 W6', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200791', 'name': '连接类型', 'type': 'checkbox', 'options': [{'value': '底板安装', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_ih_108566', 'name': '额定流量  [l/min]', 'type': 'slider', 'range': {'min': 220.0, 'max': 220.0, 'count': 1}}, {'id': 'X50_atr_dc_294642', 'name': '标称尺寸', 'type': 'checkbox', 'options': [{'value': '25', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200793', 'name': '驱动类型', 'type': 'checkbox', 'options': [{'value': '电气带集成电子元件', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294631', 'name': '电源电压', 'type': 'checkbox', 'options': [{'value': '24 VDC', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294634', 'name': '电插头', 'type': 'checkbox', 'options': [{'value': '7 针连接器 (6 + PE)', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200772', 'name': '连接', 'type': 'checkbox', 'options': [{'value': '模拟，设定值 ±10 V', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200790', 'name': '液压油', 'type': 'checkbox', 'options': [{'value': 'HL,HLP,HLPD,HVLP,HVLPD,HFC', 'count': 1, 'enableNullCount': False}]}]}}
# {'totalCount': 4, 'items': [{'sku': 'R978715908', 'comparable': False, 'termCode': '气动控制阀 BAT 0811404035', 'termCodeShort': '气动控制阀 BAT 0811404035', 'attributes': {'dataSheet': 'RD29028', 'prodHierarchy': '112611061', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'dataSheet': 'RD29028', 'prodHierarchy': '112611061', 'assort': {}}}, {'sku': '0811A04035', 'comparable': False, 'termCode': '液压比例方向阀 0811404035-PU1', 'termCodeShort': '液压比例方向阀 0811404035-PU1', 'attributes': {'prodHierarchy': '112611061', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AN'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AN'}}, 'iamAttributes': {'prodHierarchy': '112611061', 'assort': {}}}, {'sku': '0811J04035', 'comparable': False, 'termCode': '液压比例方向阀 0811404035-PU7', 'termCodeShort': '液压比例方向阀 0811404035-PU7', 'attributes': {'prodHierarchy': '112611061', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AN'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AN'}}, 'iamAttributes': {'prodHierarchy': '112611061', 'assort': {}}}, {'sku': '0811404035', 'comparable': False, 'termCode': '液压比例方向阀 4WRPH6C3B24L-2X/G24Z4/M', 'termCodeShort': '液压比例方向阀 4WRPH6C3B24L-2X/G24Z4/M', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD29028', 'prodHierarchy': '11261000S', 'pageId': 'p652375', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'SV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'SV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD29028', 'prodHierarchy': '11261000S', 'pageId': 'p652375', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 4, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902162400', 'comparable': True, 'termCode': '轴向柱塞泵 A17FNO125/10NLWK0E81-0', 'termCodeShort': '轴向柱塞泵 A17FNO125/10NLWK0E81-0', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/a4524e03-a745-498d-8377-4f85e147ee3b/dc_ecommerce_thumbnail_jpg', 'shortDescription': 'A17FNO，调节单元，开式回路，中等压力，公称尺寸：125 cm³', 'attributes': {'catalogId': 'MH', 'dataSheet': '211.22.65.36', 'prodHierarchy': '811114631', 'pageId': 'p662657', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'MH', 'dataSheet': '211.22.65.36', 'prodHierarchy': '811114631', 'pageId': 'p662657', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_mobile', 'label': '移动液压系统', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_3629968', 'name': '应用领域', 'type': 'checkbox', 'options': [{'value': '移动应用', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_3631739', 'name': '工作模式', 'type': 'checkbox', 'options': [{'value': '开式回路', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_3631743', 'name': '设计', 'type': 'checkbox', 'options': [{'value': '斜轴', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_3631770', 'name': '产品系列', 'type': 'checkbox', 'options': [{'value': 'A17F', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_281722', 'name': '尺寸（排量）', 'type': 'checkbox', 'options': [{'value': '125', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_281764', 'name': '连接和紧固螺纹', 'type': 'checkbox', 'options': [{'value': '公制', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_281765', 'name': '旋转方向', 'type': 'checkbox', 'options': [{'value': '左边', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_281700', 'name': '轴端', 'type': 'checkbox', 'options': [{'value': '花键轴，类似于 DIN ISO 14', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_281691', 'name': '安装法兰', 'type': 'checkbox', 'options': [{'value': 'ISO 7653-1985', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_281799', 'name': '最大流量', 'type': 'slider', 'range': {'min': 225.0, 'max': 225.0, 'count': 1}}]}}
# {'totalCount': 1, 'items': [{'sku': 'R900029441', 'comparable': False, 'termCode': '发热元件 AB32-10/2 E 230', 'termCodeShort': '发热元件 AB32-10/2 E 230', 'attributes': {'dataSheet': 'AB 03210', 'prodHierarchy': '142850140', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'dataSheet': 'AB 03210', 'prodHierarchy': '142850140', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900986089', 'comparable': False, 'termCode': '截流蝶阀 ZIVA-Z_220140100G1-NBR+RH', 'termCodeShort': '截流蝶阀 ZIVA-Z_220140100G1-NBR+RH', 'attributes': {'dataSheet': 'DCCS11040-311', 'prodHierarchy': '142870120', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'dataSheet': 'DCCS11040-311', 'prodHierarchy': '142870120', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900986107', 'comparable': False, 'termCode': '截流蝶阀 ZIVA-Z_220140100G1-NBR+RH+BLSO', 'termCodeShort': '截流蝶阀 ZIVA-Z_220140100G1-NBR+RH+BLSO', 'attributes': {'dataSheet': 'DCCS11040-311', 'prodHierarchy': '142870120', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'dataSheet': 'DCCS11040-311', 'prodHierarchy': '142870120', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R901066117', 'comparable': False, 'termCode': '液位开关 ABZMS-36-1X/0370M-K24', 'termCodeShort': '液位开关 ABZMS-36-1X/0370M-K24', 'attributes': {'dataSheet': 'RD50214', 'prodHierarchy': '142810120', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'dataSheet': 'RD50214', 'prodHierarchy': '142810120', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R901066119', 'comparable': False, 'termCode': '液位开关 ABZMS-36-1X/0800M-K24', 'termCodeShort': '液位开关 ABZMS-36-1X/0800M-K24', 'attributes': {'dataSheet': 'RD50214', 'prodHierarchy': '142810220', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'dataSheet': 'RD50214', 'prodHierarchy': '142810220', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900506079', 'comparable': False, 'termCode': '制动阀 FD 16 KA2X/B06V', 'termCodeShort': '制动阀 FD 16 KA2X/B06V', 'attributes': {'catalogId': 'MH', 'dataSheet': 'RD27551', 'prodHierarchy': '855511602', 'pageId': 'p662765', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'MH', 'dataSheet': 'RD27551', 'prodHierarchy': '855511602', 'pageId': 'p662765', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_mobile', 'label': '移动液压系统', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900525176', 'comparable': False, 'termCode': '制动阀 FD 32 FB2X/300B00V', 'termCodeShort': '制动阀 FD 32 FB2X/300B00V', 'attributes': {'catalogId': 'MH', 'dataSheet': 'RD27551', 'prodHierarchy': '855513202', 'pageId': 'p662765', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'MH', 'dataSheet': 'RD27551', 'prodHierarchy': '855513202', 'pageId': 'p662765', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_mobile', 'label': '移动液压系统', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902481151', 'comparable': False, 'termCodeShort': '轴向柱塞泵 LA4VSG125+LA4VSO40+', 'attributes': {'catalogId': 'IH', 'prodHierarchy': '814243332', 'pageId': 'p699506', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'prodHierarchy': '814243332', 'pageId': 'p699506', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R901178646', 'comparable': True, 'termCode': '逻辑阀盖板 LFA40DBU2A2-7X/100A050', 'termCodeShort': '逻辑阀盖板 LFA40DBU2A2-7X/100A050', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/ff464c56-52a7-4be8-bc67-2b7260789c48/dc_ecommerce_thumbnail_jpg', 'shortDescription': '公称尺寸 40，手动压力设置，双倍，可切换，带安装面 ISO4401', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD21050', 'prodHierarchy': '111622407', 'pageId': 'p796062', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD21050', 'prodHierarchy': '111622407', 'pageId': 'p796062', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_3631770', 'name': '产品系列', 'type': 'checkbox', 'options': [{'value': 'LFA', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200766', 'name': '最大压力  [bar]', 'type': 'slider', 'range': {'min': 400.0, 'max': 400.0, 'count': 1}}, {'id': 'X50_atr_dc_200791', 'name': '连接类型', 'type': 'checkbox', 'options': [{'value': '底板安装', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294642', 'name': '标称尺寸', 'type': 'checkbox', 'options': [{'value': '40', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200793', 'name': '驱动类型', 'type': 'checkbox', 'options': [{'value': '手动压力调节', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200790', 'name': '液压油', 'type': 'checkbox', 'options': [{'value': 'HL,HLP,HLPD,HVLP,HVLPD,HFC', 'count': 1, 'enableNullCount': False}]}]}}
# {'totalCount': 2, 'items': [{'sku': '1815500293', 'comparable': False, 'termCode': '逻辑阀盖板 LFR25D-1X/F', 'termCodeShort': '逻辑阀盖板 LFR25D-1X/F', 'attributes': {'catalogId': 'IH', 'dataSheet': '1987761105', 'prodHierarchy': '111689001', 'pageId': 'p1097452', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': '1987761105', 'prodHierarchy': '111689001', 'pageId': 'p1097452', 'assort': {}}}, {'sku': 'R978716226', 'comparable': False, 'termCode': '逻辑阀盖板 BAT 1815500293', 'termCodeShort': '逻辑阀盖板 BAT 1815500293', 'attributes': {'dataSheet': '1987761105', 'prodHierarchy': '111689001', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'dataSheet': '1987761105', 'prodHierarchy': '111689001', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 2, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 2, 'items': [{'sku': '1815500322', 'comparable': False, 'termCode': '逻辑阀盖板 LFR25H4-1X/FX12', 'termCodeShort': '逻辑阀盖板 LFR25H4-1X/FX12', 'attributes': {'catalogId': 'IH', 'dataSheet': '1987761105', 'prodHierarchy': '111689001', 'pageId': 'p1097452', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': '1987761105', 'prodHierarchy': '111689001', 'pageId': 'p1097452', 'assort': {}}}, {'sku': 'R978716172', 'comparable': False, 'termCode': '逻辑阀盖板 BAT 1815500322', 'termCodeShort': '逻辑阀盖板 BAT 1815500322', 'attributes': {'dataSheet': '1987761105', 'prodHierarchy': '111689001', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'dataSheet': '1987761105', 'prodHierarchy': '111689001', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 2, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 2, 'items': [{'sku': '1818509295', 'comparable': False, 'termCode': '逻辑阀 LR25F10E1X/', 'termCodeShort': '逻辑阀 LR25F10E1X/', 'attributes': {'catalogId': 'IH', 'dataSheet': '1987761105', 'prodHierarchy': '111682001', 'pageId': 'p1097408', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': '1987761105', 'prodHierarchy': '111682001', 'pageId': 'p1097408', 'assort': {}}}, {'sku': 'R901449745', 'comparable': False, 'termCode': '逻辑阀 1818509295-PU1', 'termCodeShort': '逻辑阀 1818509295-PU1', 'attributes': {'dataSheet': '1987761105', 'prodHierarchy': '111682001', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'dataSheet': '1987761105', 'prodHierarchy': '111682001', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 2, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 2, 'items': [{'sku': '1818509298', 'comparable': False, 'termCode': '逻辑阀 LR25F10K1X/', 'termCodeShort': '逻辑阀 LR25F10K1X/', 'attributes': {'catalogId': 'IH', 'dataSheet': '1987761105', 'prodHierarchy': '111682001', 'pageId': 'p1097408', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': '1987761105', 'prodHierarchy': '111682001', 'pageId': 'p1097408', 'assort': {}}}, {'sku': 'R978716035', 'comparable': False, 'termCode': '逻辑阀 BAT 1818509298', 'termCodeShort': '逻辑阀 BAT 1818509298', 'attributes': {'dataSheet': '1987761105', 'prodHierarchy': '111682001', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'dataSheet': '1987761105', 'prodHierarchy': '111682001', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 2, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900549687', 'comparable': True, 'termCode': '流量控制阀 Z2FRM6CB2-2X/32QRV', 'termCodeShort': '流量控制阀 Z2FRM6CB2-2X/32QRV', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/5bb40c26-86c1-4b2d-b772-d701c9c68204/dc_ecommerce_thumbnail_jpg', 'shortDescription': '公称尺寸 6，A2 → A1，B2 → B1，机械操作', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD28164', 'prodHierarchy': '111411062', 'pageId': 'p686891', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD28164', 'prodHierarchy': '111411062', 'pageId': 'p686891', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_3631770', 'name': '产品系列', 'type': 'checkbox', 'options': [{'value': 'Z2FRM6', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200766', 'name': '最大压力  [bar]', 'type': 'slider', 'range': {'min': 315.0, 'max': 315.0, 'count': 1}}, {'id': 'X50_atr_dc_200767', 'name': '最大体积流量  [l/min]', 'type': 'slider', 'range': {'min': 32.0, 'max': 32.0, 'count': 1}}, {'id': 'X50_atr_dc_200795', 'name': '活塞符号', 'type': 'checkbox', 'options': [{'value': 'A2 → A1，B2 → B1', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200791', 'name': '连接类型', 'type': 'checkbox', 'options': [{'value': '中间组装', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294642', 'name': '标称尺寸', 'type': 'checkbox', 'options': [{'value': '6', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200793', 'name': '驱动类型', 'type': 'checkbox', 'options': [{'value': '带机械操作', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200790', 'name': '液压油', 'type': 'checkbox', 'options': [{'value': 'HL,HLP,HLPD,HVLP,HVLPD,HETG,HEES,HEPG,HFDU,HFDR', 'count': 1, 'enableNullCount': False}]}]}}
# {'totalCount': 1, 'items': [{'sku': 'R900752827', 'comparable': True, 'termCode': '液压方向短管阀 Z4WEH10D24-5X/4KEG24N9ETK4', 'termCodeShort': '液压方向短管阀 Z4WEH10D24-5X/4KEG24N9ETK4', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/241f75bb-b364-4e4b-9f49-4565f68054eb/dc_ecommerce_thumbnail_jpg', 'shortDescription': '公称尺寸 10，符号 D24，带电磁操作，24 VDC', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD24755', 'prodHierarchy': '111111105', 'pageId': 'p667007', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD24755', 'prodHierarchy': '111111105', 'pageId': 'p667007', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_3631770', 'name': '产品系列', 'type': 'checkbox', 'options': [{'value': 'Z.WEH10', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200766', 'name': '最大压力  [bar]', 'type': 'slider', 'range': {'min': 315.0, 'max': 315.0, 'count': 1}}, {'id': 'X50_atr_dc_200767', 'name': '最大体积流量  [l/min]', 'type': 'slider', 'range': {'min': 160.0, 'max': 160.0, 'count': 1}}, {'id': 'X50_atr_dc_200795', 'name': '活塞符号', 'type': 'checkbox', 'options': [{'value': '符号 D24', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200791', 'name': '连接类型', 'type': 'checkbox', 'options': [{'value': '叠加阀板', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294642', 'name': '标称尺寸', 'type': 'checkbox', 'options': [{'value': '10', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200793', 'name': '驱动类型', 'type': 'checkbox', 'options': [{'value': '带电磁操作', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294631', 'name': '电源电压', 'type': 'checkbox', 'options': [{'value': '24 VDC', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294634', 'name': '电插头', 'type': 'checkbox', 'options': [{'value': '3 针连接器 (2 + PE)', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200790', 'name': '液压油', 'type': 'checkbox', 'options': [{'value': 'HL,HLP,HETG', 'count': 1, 'enableNullCount': False}]}]}}
# {'totalCount': 1, 'items': [{'sku': 'R900752823', 'comparable': True, 'termCode': '液压方向短管阀 Z4WEH10E68-5X/4KEG24N9ETK4', 'termCodeShort': '液压方向短管阀 Z4WEH10E68-5X/4KEG24N9ETK4', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/241f75bb-b364-4e4b-9f49-4565f68054eb/dc_ecommerce_thumbnail_jpg', 'shortDescription': '公称尺寸 10，符号 E68，带电磁操作，24 VDC', 'attributes': {'catalogId': 'IH', 'dataSheet': 'RD24755', 'prodHierarchy': '111111105', 'pageId': 'p667007', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'dataSheet': 'RD24755', 'prodHierarchy': '111111105', 'pageId': 'p667007', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_3631770', 'name': '产品系列', 'type': 'checkbox', 'options': [{'value': 'Z.WEH10', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200766', 'name': '最大压力  [bar]', 'type': 'slider', 'range': {'min': 315.0, 'max': 315.0, 'count': 1}}, {'id': 'X50_atr_dc_200767', 'name': '最大体积流量  [l/min]', 'type': 'slider', 'range': {'min': 160.0, 'max': 160.0, 'count': 1}}, {'id': 'X50_atr_dc_200795', 'name': '活塞符号', 'type': 'checkbox', 'options': [{'value': '符号 E68', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200791', 'name': '连接类型', 'type': 'checkbox', 'options': [{'value': '叠加阀板', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294642', 'name': '标称尺寸', 'type': 'checkbox', 'options': [{'value': '10', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200793', 'name': '驱动类型', 'type': 'checkbox', 'options': [{'value': '带电磁操作', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294631', 'name': '电源电压', 'type': 'checkbox', 'options': [{'value': '24 VDC', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_294634', 'name': '电插头', 'type': 'checkbox', 'options': [{'value': '3 针连接器 (2 + PE)', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_200790', 'name': '液压油', 'type': 'checkbox', 'options': [{'value': 'HL,HLP,HETG', 'count': 1, 'enableNullCount': False}]}]}}
# {'totalCount': 1, 'items': [{'sku': 'R910960735', 'comparable': False, 'termCode': '滚柱轴承 NUP 35X 62X 20VH  F- 84874.3', 'termCodeShort': '滚柱轴承 NUP 35X 62X 20VH  F- 84874.3', 'attributes': {'catalogId': 'SP', 'dataSheet': '93 3613 17 700', 'prodHierarchy': '819000000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '93 3613 17 700', 'prodHierarchy': '819000000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R928019845', 'comparable': False, 'termCode': '回油过滤器 10TEN0063-PWR10A00-V2,2-M-R4', 'termCodeShort': '回油过滤器 10TEN0063-PWR10A00-V2,2-M-R4', 'attributes': {'catalogId': 'IH', 'prodHierarchy': '171212100', 'pageId': 'p652549', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'IH', 'prodHierarchy': '171212100', 'pageId': 'p652549', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R900579998', 'comparable': False, 'termCode': '液压比例方向阀 2WRC63K001-1X/S/M', 'termCodeShort': '液压比例方向阀 2WRC63K001-1X/S/M', 'attributes': {'catalogId': 'SP', 'dataSheet': 'RD29135', 'prodHierarchy': '11241000S', 'pageId': 'p684949', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'SV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'SV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': 'RD29135', 'prodHierarchy': '11241000S', 'pageId': 'p684949', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902473432', 'comparable': False, 'termCodeShort': '轴向柱塞泵 A  A10VSO 28', 'attributes': {'catalogId': 'IH', 'prodHierarchy': '814232413', 'pageId': 'p699415', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'SV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'SV'}}, 'iamAttributes': {'catalogId': 'IH', 'prodHierarchy': '814232413', 'pageId': 'p699415', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_industrial', 'label': '工业液压', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 0, 'items': [], 'facets': {'attributes': [], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902531046', 'comparable': False, 'termCode': '移换活塞 A4VS 250/350 DR+LR', 'termCodeShort': '移换活塞 A4VS 250/350 DR+LR', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902530758', 'comparable': False, 'termCode': '移换活塞 A4VS 250/355 HD/30', 'termCodeShort': '移换活塞 A4VS 250/355 HD/30', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910944483', 'comparable': False, 'termCode': '指示设备 A4 40/10 -P', 'termCodeShort': '指示设备 A4 40/10 -P', 'attributes': {'catalogId': 'SP', 'dataSheet': '97 6748 17 700', 'prodHierarchy': '819920000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '97 6748 17 700', 'prodHierarchy': '819920000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902455074', 'comparable': False, 'termCode': '辅助泵 A4CSG 250/355/80CC R/L', 'termCodeShort': '辅助泵 A4CSG 250/355/80CC R/L', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819920000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819920000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': '0510425041', 'comparable': True, 'termCode': '齿轮泵 AZPF-11-008RRR20KB-S0081', 'termCodeShort': '齿轮泵 AZPF-11-008RRR20KB-S0081', 'productImageUrl': 'https://assets.rexroth.mam.bosch.tech/assets/api/e6399865-0493-428e-b1b6-1727cb6ac03f/dc_ecommerce_thumbnail_jpg', 'shortDescription': '8 cm^3/转, 右转, 花键轴 SAE J744 16-4 (9T 16/32SP), SAE J744 82-2 (A), 螺纹 UN-2B SAE O 型圈', 'attributes': {'catalogId': 'MH', 'dataSheet': 'RD10089', 'prodHierarchy': '835400300', 'pageId': 'p662692', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'MH', 'dataSheet': 'RD10089', 'prodHierarchy': '835400300', 'pageId': 'p662692', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}, {'id': 'productGroupLevel1', 'options': [{'value': 'pgr_mobile', 'label': '移动液压系统', 'count': 1, 'enableNullCount': False}]}], 'pim': [{'id': 'X50_atr_dc_198601', 'name': '流量', 'type': 'slider', 'range': {'min': 32.0, 'max': 32.0, 'count': 1}}, {'id': 'X50_atr_dc_198547', 'name': '排量', 'type': 'slider', 'range': {'min': 8.0, 'max': 8.0, 'count': 1}}, {'id': 'X50_atr_dc_198520', 'name': '间歇性压力', 'type': 'slider', 'range': {'min': 280.0, 'max': 280.0, 'count': 1}}, {'id': 'X50_atr_dc_198526', 'name': '功能', 'type': 'slider', 'range': {'min': 4000.0, 'max': 4000.0, 'count': 1}}, {'id': 'X50_atr_dc_198549', 'name': '驱动轴', 'type': 'checkbox', 'options': [{'value': '花键轴 SAE J744 16-4 (9T 1632SP)', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_198548', 'name': '旋转方向', 'type': 'checkbox', 'options': [{'value': '右转', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_198550', 'name': '前端盖', 'type': 'checkbox', 'options': [{'value': 'SAE J744 82-2 (A)', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_213169', 'name': '築屋材料', 'type': 'checkbox', 'options': [{'value': '铝', 'count': 1, 'enableNullCount': False}]}, {'id': 'X50_atr_dc_198519', 'name': '噪音水平', 'type': 'checkbox', 'options': [{'value': '标准噪声等级', 'count': 1, 'enableNullCount': False}]}]}}
# {'totalCount': 1, 'items': [{'sku': 'R910946522', 'comparable': False, 'termCode': '轴瓦 A4VS 125/22/30', 'termCodeShort': '轴瓦 A4VS 125/22/30', 'attributes': {'catalogId': 'SP', 'dataSheet': '95 4901 25 700', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '95 4901 25 700', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910902778', 'comparable': False, 'termCode': '轴瓦 A10V 28', 'termCodeShort': '轴瓦 A10V 28', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910906881', 'comparable': False, 'termCode': '轴瓦 A10V100', 'termCodeShort': '轴瓦 A10V100', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910918174', 'comparable': False, 'termCode': '轴瓦 A10V140', 'termCodeShort': '轴瓦 A10V140', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910900198', 'comparable': False, 'termCode': '轴瓦 A10V 45', 'termCodeShort': '轴瓦 A10V 45', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910946525', 'comparable': False, 'termCode': '轴瓦 A4VS 180/22/30', 'termCodeShort': '轴瓦 A4VS 180/22/30', 'attributes': {'catalogId': 'SP', 'dataSheet': '95 4901 28 700', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '95 4901 28 700', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R909921186', 'comparable': False, 'termCode': '斜盘            21628.2100', 'termCodeShort': '斜盘            21628.2100', 'attributes': {'catalogId': 'SP', 'dataSheet': '216.28.21.00', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '216.28.21.00', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902066600', 'comparable': False, 'termCode': '半圆轨道副 144X153,4X27', 'termCodeShort': '半圆轨道副 144X153,4X27', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902066599', 'comparable': False, 'termCode': '半圆轨道副 130X138,4X18', 'termCodeShort': '半圆轨道副 130X138,4X18', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902600957', 'comparable': False, 'termCode': '半圆轴承 120X144X36,3 35.1', 'termCodeShort': '半圆轴承 120X144X36,3 35.1', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910989439', 'comparable': False, 'termCode': '轴瓦 A4VS  40/10', 'termCodeShort': '轴瓦 A4VS  40/10', 'attributes': {'catalogId': 'SP', 'dataSheet': '91 4901 00 700', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '91 4901 00 700', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# ...
# {'totalCount': 1, 'items': [{'sku': 'R902650865', 'comparable': False, 'termCode': '内六角圆柱头螺钉 DIN912-M8X35-8.8-MK11#25NM', 'termCodeShort': '内六角圆柱头螺钉 DIN912-M8X35-8.8-MK11#25NM', 'attributes': {'catalogId': 'SP', 'dataSheet': 'DIN912', 'prodHierarchy': '819000000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': 'DIN912', 'prodHierarchy': '819000000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R913037932', 'comparable': False, 'termCode': '开槽圆螺母 DRS M55X2-13,2', 'termCodeShort': '开槽圆螺母 DRS M55X2-13,2', 'attributes': {'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AN'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AN'}}, 'iamAttributes': {'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902650867', 'comparable': False, 'termCode': '内六角圆柱头螺钉 DIN912-M10X40-8.8-MK12#51NM', 'termCodeShort': '内六角圆柱头螺钉 DIN912-M10X40-8.8-MK12#51NM', 'attributes': {'catalogId': 'SP', 'dataSheet': 'DIN912', 'prodHierarchy': '819000000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': 'DIN912', 'prodHierarchy': '819000000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902283574', 'comparable': False, 'termCode': '衬套 23122.2000', 'termCodeShort': '衬套 23122.2000', 'attributes': {'catalogId': 'SP', 'dataSheet': '231.22.20.00', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '231.22.20.00', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902418070', 'comparable': False, 'termCode': '过渡板 A4CSG125 355 EPG/30X-V-S1269', 'termCodeShort': '过渡板 A4CSG125 355 EPG/30X-V-S1269', 'attributes': {'catalogId': 'SP', 'dataSheet': '97 4260 00 700', 'prodHierarchy': '819920000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '97 4260 00 700', 'prodHierarchy': '819920000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910978478', 'comparable': False, 'termCode': '滚柱轴承 F-202578.1   INA', 'termCodeShort': '滚柱轴承 F-202578.1   INA', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819000000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819000000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902117772', 'comparable': False, 'termCode': '传动轴 TRIEBWELLE MIT ZAHNRING       20124.4310', 'termCodeShort': '传动轴 TRIEBWELLE MIT ZAHNRING       20124.4310', 'attributes': {'catalogId': 'SP', 'dataSheet': '201.24.43.10', 'prodHierarchy': '819920000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '201.24.43.10', 'prodHierarchy': '819920000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910928220', 'comparable': False, 'termCode': '滚柱轴承 F-217040      INA', 'termCodeShort': '滚柱轴承 F-217040      INA', 'attributes': {'catalogId': 'SP', 'dataSheet': '93 3613 17 040', 'prodHierarchy': '819000000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '93 3613 17 040', 'prodHierarchy': '819000000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910931557', 'comparable': False, 'termCode': '滚柱轴承 ZYL.ROL.LAG.  NJ 2207 E       DIN   5412', 'termCodeShort': '滚柱轴承 ZYL.ROL.LAG.  NJ 2207 E       DIN   5412', 'attributes': {'catalogId': 'SP', 'dataSheet': '93 3612 02 207', 'prodHierarchy': '819000000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '93 3612 02 207', 'prodHierarchy': '819000000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910934966', 'comparable': False, 'termCode': '滚柱轴承 ZYL.ROL.LAG.  NJ  310 EC/C3   DIN   5412', 'termCodeShort': '滚柱轴承 ZYL.ROL.LAG.  NJ  310 EC/C3   DIN   5412', 'attributes': {'catalogId': 'SP', 'dataSheet': '93 3612 00 310', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '93 3612 00 310', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R902570169', 'comparable': False, 'termCode': '切片 A4VS 125', 'termCodeShort': '切片 A4VS 125', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AE'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910960737', 'comparable': False, 'termCode': '滚柱轴承 NUP 50X 90X 27VH  F-202808.3', 'termCodeShort': '滚柱轴承 NUP 50X 90X 27VH  F-202808.3', 'attributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910960739', 'comparable': False, 'termCode': '滚柱轴承 NUP 65X120X 33VH  F-207407.2', 'termCodeShort': '滚柱轴承 NUP 65X120X 33VH  F-207407.2', 'attributes': {'catalogId': 'SP', 'dataSheet': '93 3613 32 700', 'prodHierarchy': '819000000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AV'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': '93 3613 32 700', 'prodHierarchy': '819000000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# {'totalCount': 1, 'items': [{'sku': 'R910109479', 'comparable': False, 'termCode': '内六角圆柱头螺钉 DIN912-M8X25-8.8 #25NM', 'termCodeShort': '内六角圆柱头螺钉 DIN912-M8X25-8.8 #25NM', 'attributes': {'catalogId': 'SP', 'dataSheet': 'DIN912', 'prodHierarchy': '819910000', 'assort': {}, 'sellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}, 'globalSellableInfo': {'shopOrderable': False, 'distrStatus': 'AL'}}, 'iamAttributes': {'catalogId': 'SP', 'dataSheet': 'DIN912', 'prodHierarchy': '819910000', 'assort': {}}}], 'facets': {'attributes': [{'id': 'shopOrderable', 'options': [{'value': 'false', 'count': 1, 'enableNullCount': False}]}], 'pim': []}}
# ['流量控制阀 2FRM6B76-3X/32QMV', '流量控制阀 2FRM 6 K2-1X/32QRV', '移换活塞 A4VS 125/180 DR+LR', '液压比例方向阀 4WRKE10E50L-3X/6EG24ETK31/F1D3M', '液压比例方向阀 4WRKE16E200L-3X/6EG24ETK31/F1D3V', '液压比例方向阀 4WRKE16W8-200L-3X/6EG24EK31/F1D3M', '液压比例方向阀 4WRKE25W6-220L-3X/6EG24EK31/A1D3M', '气动控制阀 BAT 0811404035', '轴向柱塞泵 A17FNO125/10NLWK0E81-0', '发热元件 AB32-10/2 E 230', '截流蝶阀 ZIVA-Z_220140100G1-NBR+RH', '截流蝶阀 ZIVA-Z_220140100G1-NBR+RH+BLSO', '液位开关 ABZMS-36-1X/0370M-K24', '液位开关 ABZMS-36-1X/0800M-K24', '制动阀 FD 16 KA2X/B06V', '制动阀 FD 32 FB2X/300B00V', '轴向柱塞泵 LA4VSG125+LA4VSO40+', '逻辑阀盖板 LFA40DBU2A2-7X/100A050', '逻辑阀盖板 LFR25D-1X/F', '逻辑阀盖板 LFR25H4-1X/FX12', '逻辑阀 LR25F10E1X/', '逻辑阀 LR25F10K1X/', '流量控制阀 Z2FRM6CB2-2X/32QRV', '液压方向短管阀 Z4WEH10D24-5X/4KEG24N9ETK4', '液压方向短管阀 Z4WEH10E68-5X/4KEG24N9ETK4', '滚柱轴承 NUP 35X 62X 20VH  F- 84874.3', '回油过滤器 10TEN0063-PWR10A00-V2,2-M-R4', '液压比例方向阀 2WRC63K001-1X/S/M', '轴向柱塞泵 A  A10VSO 28', '', '移换活塞 A4VS 250/350 DR+LR', '移换活塞 A4VS 250/355 HD/30', '指示设备 A4 40/10 -P', '辅助泵 A4CSG 250/355/80CC R/L', '齿轮泵 AZPF-11-008RRR20KB-S0081', '轴瓦 A4VS 125/22/30', '轴瓦 A10V 28', '轴瓦 A10V100', '轴瓦 A10V140', '轴瓦 A10V 45', '轴瓦 A4VS 180/22/30', '斜盘            21628.2100', '半圆轨道副 144X153,4X27', '半圆轨道副 130X138,4X18', '半圆轴承 120X144X36,3 35.1', '轴瓦 A4VS  40/10', '轴瓦 A4VS  71/10', "中间塞子 'R'        20122.3390", "中间塞子 'R'        20122.3390", "中间塞子 'R'        20122.3390", "中间塞子 'R'        20122.3390", "中间塞子 'R'        20114.3390", "压缩弹簧 '2,40/  8,00/ 24,00'", '压缩弹簧 4,7  1,10   11,17', '压缩弹簧 5,3  1,20 12,67', '控制透镜 STEUERLINSE-WEICHBEA.S.ZCHNG.R902065582', '控制透镜 STEUERLINSE-WEICHBEA.S.ZCHNG.R909650453', '控制透镜 STEUERLINSE-WEICHBEA.S.ZCHNG.R902065583', '控制透镜 STEUERLINSE-WEICHBEA.S.ZCHNG.R902065583', '控制透镜 STEUERLINSE-WEICHBEA.S.ZCHNG.R902065583', '控制透镜 STEUERLINSE-WEICHBEA.S.ZCHNG.R909650454', '控制阀 A4VSG250/355EPD/30X-V', "配流盘 'R'        20124.0690", "配流盘 'R'        20131.0690", '配流盘 A11V O 190 R   21628.', '配流盘 A11V O 190 L', "配流盘 'R'        20121.0690", "配流盘 'R'        20124.1890", '调节阀 A4VS DR P', '调节阀 A4VS DR P      -SO228', '调节阀 A4VS DRG P', '控制阀 A4VSG125/180EPD/30X-V', '轴瓦 A4VS 250/22/30', '斜盘            21620.2100', '斜盘            21620.2100', '碟簧            23017.0301', '碟簧            23025.0301', '滚柱轴承 65X120X 33 A4 250', '滚柱轴承 NUP52X106X35', '滚柱轴承 55X100X 31 A4 180', '滚柱轴承 F-202578     INA', '滚柱轴承 RNU 42,01X72X30', '滚柱轴承 RNU41,31X67X27', '滚柱轴承 RNU 42,01X 72X 30', '滚柱轴承 A-NUP 50X 90X 27', "缸体 A10V 28 'R'", '缸体 MB A4VS 250M/30', '缸体 A10V100', "缸体 'R'        20125.0490", '缸体 A10V 71/31', '缸体 A10V140', "缸体 'R'        20124.0792", "缸体 MB A4VS 125M/30'KC'", "缸体 M.B. A11VO 190 'R'", '缸体 MB A4XSX 370K/30', "缸体 'R'        20121.0792", "缸体 'R'        20125.0392", "缸体 'R'        20131.0391", '缸体 A10VO 18', '密封套件 A8VO107LA0K/63R1-NZG05K0*0', "缸体 A10V 45 'R'", "缸体 MB A4VS 125K/30'KC'", "缸体 M. BUCHSEN 'R'      21620", '缸体 MB A4VS 180K/30', "缸体 MB A4VS 40M/10'KC'", '缸体 MIT STEUERPLATTE L.', '片弹簧            20125.0790', '配流盘 A10V 140 R BESCHICHTET', '配流盘 A10V  18/31R', '配流盘 A10V  45 R', '配流盘 A10V  28 R', "配流盘 R48 'R'   A11VO260R", '配流盘 A4XSG 355/30R', '配流盘 A4XSO 125/30R', '配流盘 A4XSO 180/30 R', '配流盘 A4XSO 250/30R', '配流盘 A4XSO  40 R', '配流盘 A4XSO  71 R', '传动轴 MIT ZAHNRING   20121.', '配流盘 EA4XSO250/30R ST.RAND', '配流盘 EA4XSO 125/30R', "冠状弹簧 'AUSLESETEILE' 20125.", "驱动轴 EA10V 100 PN 'R'", "传动轴 'R'        70825.8000", '传动轴            20125.0521', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', '传动轴 W 40X2X18-0     21620', "驱动轴 A10V  28 SN 'R'", "驱动轴 A4VS 125/22 PK 'R'", '驱动轴            20125.0511', "驱动轴 A10V  28 PN 'R'", "驱动轴 A4CSG125/30ZK'R'-S1111", "驱动轴 A4VS 125/30 PN 'R'", "驱动轴 EA10V 140 PN 'R'", "驱动轴 A10V  45 PN 'R'", '进给轮 A4VS 125', '进给轮 A4VS 180', '进给轮 A4VS 250', '指示设备 E A4VS 125/180/30', '指示设备 E A4VS 250/355/30', ' 88,57-DKAR00153-N7 ...
# ['', 'https://assets.rexroth.mam.bosch.tech/assets/api/50f6e2be-c3c9-423c-a52d-537035d705f2/dc_ecommerce_thumbnail_png', '', 'https://assets.rexroth.mam.bosch.tech/assets/api/9d2c04f7-acac-4f90-be0a-2a52c0ac95a1/dc_ecommerce_thumbnail_jpg', '', '', 'https://assets.rexroth.mam.bosch.tech/assets/api/9d2c04f7-acac-4f90-be0a-2a52c0ac95a1/dc_ecommerce_thumbnail_jpg', '', 'https://assets.rexroth.mam.bosch.tech/assets/api/a4524e03-a745-498d-8377-4f85e147ee3b/dc_ecommerce_thumbnail_jpg', '', '', '', '', '', '', '', '', 'https://assets.rexroth.mam.bosch.tech/assets/api/ff464c56-52a7-4be8-bc67-2b7260789c48/dc_ecommerce_thumbnail_jpg', '', '', '', '', 'https://assets.rexroth.mam.bosch.tech/assets/api/5bb40c26-86c1-4b2d-b772-d701c9c68204/dc_ecommerce_thumbnail_jpg', 'https://assets.rexroth.mam.bosch.tech/assets/api/241f75bb-b364-4e4b-9f49-4565f68054eb/dc_ecommerce_thumbnail_jpg', 'https://assets.rexroth.mam.bosch.tech/assets/api/241f75bb-b364-4e4b-9f49-4565f68054eb/dc_ecommerce_thumbnail_jpg', '', '', '', '', '', '', '', '', '', 'https://assets.rexroth.mam.bosch.tech/assets/api/e6399865-0493-428e-b1b6-1727cb6ac03f/dc_ecommerce_thumbnail_jpg', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# /var/folders/bz/pmqfsmx511ndlykxz190zty40000gn/T/ipykernel_26387/2818980698.py:132: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
